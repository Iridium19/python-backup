# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import scipy.optimize as opt
from scipy.optimize import curve_fit

# %% [markdown]
# # Daten Import

# %%
Wellenlänge1, Absorbtion1 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\1.csv',skiprows=2, delimiter=',',unpack=True)
Wellenlänge2, Absorbtion2 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\2.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge3, Absorbtion3 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\3.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge4, Absorbtion4 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\4.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge5, Absorbtion5 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\5.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge6, Absorbtion6 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\64.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge7, Absorbtion7 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\7.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge8, Absorbtion8 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\8.csv',skiprows=2,delimiter=',',unpack=True)
Wellenlänge9, Absorbtion9 = np.loadtxt(r'C:\Users\Justus\Desktop\Gruppe12\9.csv',skiprows=2,delimiter=',',unpack=True)

# %% [markdown]
# # Absortionsmaximum

# %%
m1=max(Absorbtion1)
print(m1) #423
w1e=423
m2=max(Absorbtion2)
print(m2) #528
w2e=558
m3=max(Absorbtion3)
print(m3) #
w3e=653
m4=max(Absorbtion4)
print(m4) #
w4e=758
m5=max(Absorbtion5)
print(m5) #
w5e=482
m6=max(Absorbtion6)
print(m6) #
w6e=605
m7=max(Absorbtion7)
print(m7) #
w7e=559
m8=max(Absorbtion8)
print(m8) #
w8e=542
m9=max(Absorbtion9)
print(m9) #
w9e=707
# Out:
# 1.6681
# 2.0742
# 1.9856
# 0.7944
# 2.9276
# 2.848
# 1.8499
# 2.0014
# 1.3379

# %% [markdown]
# # Plotten Aufgabe 2

# %%
plt.plot(Wellenlänge1, (Absorbtion1/1.6681),label='Farbstoff 1', color='greenyellow')
plt.plot(Wellenlänge2, (Absorbtion2/2.0742),label='Farbstoff 2', color='pink')
plt.plot(Wellenlänge3, (Absorbtion3/1.9856),label='Farbstoff 3', color='blue')
plt.plot(Wellenlänge4, (Absorbtion4/0.7944),label='Farbstoff 4', color='cyan')





plt.xlim((400,900))
plt.legend()
plt.ylabel('Relative Absorbtion')
plt.xlabel('Wellenlänge $\lambda$ [nm]')
# Out:
# Text(0.5, 0, 'Wellenlänge $\\lambda$ [nm]')

# %% [markdown]
# # Plotten Aufgabe 4

# %%
plt.plot(Wellenlänge2, (Absorbtion2/2.0742),label='Farbstoff 2', color='pink')
plt.plot(Wellenlänge5, (Absorbtion5/2.9276),label='Farbstoff 5', color='yellow')
plt.plot(Wellenlänge6, (Absorbtion6/2.848),label='Farbstoff 6', color='blue')






plt.xlim((400,700))
plt.legend()
plt.ylabel('Relative Absorbtion')
plt.xlabel('Wellenlänge $\lambda$ [nm]')
# Out:
# Text(0.5, 0, 'Wellenlänge $\\lambda$ [nm]')

# %% [markdown]
# # Plotten augabe 5

# %%
plt.plot(Wellenlänge2, (Absorbtion2/2.0742),label='Farbstoff 2', color='pink')
plt.plot(Wellenlänge7, (Absorbtion7/1.8499),label='Farbstoff 7', color='magenta')
plt.plot(Wellenlänge8, (Absorbtion8/2.0014),label='Farbstoff 8', color='purple')





plt.ylim((0,1.1))
plt.xlim((400,700))
plt.legend()
plt.ylabel('Relative Absorbtion')
plt.xlabel('Wellenlänge $\lambda$ [nm]')
# Out:
# Text(0.5, 0, 'Wellenlänge $\\lambda$ [nm]')

# %% [markdown]
# # Plotten aufgabe 6

# %%
plt.plot(Wellenlänge9, (Absorbtion9/1.3379),label='Farbstoff 9', color='cyan')





plt.ylim((0,1.1))
plt.xlim((400,900))
plt.legend()
plt.ylabel('Relative Absorbtion')
plt.xlabel('Wellenlänge $\lambda$ [nm]')
# Out:
# Text(0.5, 0, 'Wellenlänge $\\lambda$ [nm]')

# %% [markdown]
# # Kastenlängen

# %%
cc=140
cn=147
c2n=122
cs=181
c2s=161
co=143
c20=119

# %% [markdown]
# #Farbstoff1

# %%
F11=2*cc+cn+c2n+2*cs
F12=F11
F13=2*cc+2*cn+cs+c2s
F14=F13

array1=np.array([F11,F12,F13,F14])
Mittelwert1=np.mean(array1)
std1=np.std(array1)
Fehler1=std1/(np.sqrt(4))

# %% [markdown]
# #Farbstoff2

# %%
F21=F11+2*cc
F22=F21
F23=F13+2*cc
F24=F23

array2=np.array([F21,F22,F23,F24])
Mittelwert2=np.mean(array2)
std2=np.std(array2)
Fehler2=std2/(np.sqrt(4))

# %% [markdown]
# #Farbstoff 3

# %%
F31=F21+2*cc
F32=F31
F33=F23+2*cc
F34=F33

array3=np.array([F31,F32,F33,F34])
Mittelwert3=np.mean(array3)
std3=np.std(array3)
Fehler3=std3/(np.sqrt(4))

# %% [markdown]
# #Farbstoff4

# %%
F41=F31+2*cc
F42=F41
F43=F33+2*cc
F44=F43

array4=np.array([F41,F42,F43,F44])
Mittelwert4=np.mean(array4)
std4=np.std(array4)
Fehler4=std4/(np.sqrt(4))

# %% [markdown]
# #Farbstoff5

# %%
F51=cn+4*cc+c2n+2*co
F52=F51
F53=2*cn+4*cc+co+c20
F54=F53

array5=np.array([F51,F52,F53,F54])
Mittelwert5=np.mean(array5)
std5=np.std(array5)
Fehler5=std5/(np.sqrt(4))

# %% [markdown]
# #Farbstoff6

# %%
F61=cn+7*cc+c2n
F62=F61
F63=2*cn+7*cc
F64=F63

array6=np.array([F61,F62,F63,F64])
Mittelwert6=np.mean(array6)
std6=np.std(array6)
Fehler6=std6/(np.sqrt(4))

# %% [markdown]
# #Farbstoff 7&8

# %%
Mittelwert7=Mittelwert2
Fehler7=Fehler2

# %% [markdown]
# Farbstoff 8

# %%
F81=F11+2*cc
F82=F21
F83=F13+2*cc
F84=F23
F85=4*cc+2*cn+2*cs
array8=np.array([F81,F82,F83,F84,F85])
Mittelwert8=np.mean(array8)
std8=np.std(array8)
Fehler8=std8/(np.sqrt(5))

# %% [markdown]
# #Farbstoff9

# %%
F91=cn+10*cc+c2n
F92=F91
F93=F92
F94=F93

array9=np.array([F91,F92,F93,F94])
Mittelwert9=np.mean(array9)
std9=np.std(array9)
Fehler9=std9/(np.sqrt(3))

# %% [markdown]
# # Wellenlängetheorie

# %% [markdown]
# Konstanten definieren

# %%
m=(9.109383713*(10**-31))
h=(6.62607015*(10**-34))
c=299792458

# %% [markdown]
# Wellnlänge1

# %%
W1=(c*8*m*((Mittelwert1*(10**-12))**2))/(h*((4**2)-(3**2)))*10**9

qw1=np.sqrt((((16*m*Mittelwert1*(10**-12)*c)/(h*((4**2)-(3**2))))*(Fehler1*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge2

# %%
W2=(c*8*m*((Mittelwert2*(10**-12))**2))/(h*((5**2)-(4**2)))*10**9

qw2=np.sqrt((((16*m*Mittelwert2*(10**-12)*c)/(h*((5**2)-(4**2))))*(Fehler2*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge3

# %%
W3=(c*8*m*((Mittelwert3*(10**-12))**2))/(h*((6**2)-(5**2)))*10**9

qw3=np.sqrt((((16*m*Mittelwert3*(10**-12)*c)/(h*((6**2)-(5**2))))*(Fehler3*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge4

# %%
W4=(c*8*m*((Mittelwert4*(10**-12))**2))/(h*((7**2)-(6**2)))*10**9

qw4=np.sqrt((((16*m*Mittelwert4*(10**-12)*c)/(h*((7**2)-(6**2))))*(Fehler4*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge5

# %%
W5=(c*8*m*((Mittelwert5*(10**-12))**2))/(h*((5**2)-(4**2)))*10**9

qw5=np.sqrt((((16*m*Mittelwert5*(10**-12)*c)/(h*((5**2)-(4**2))))*(Fehler5*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge6

# %%
W6=(c*8*m*((Mittelwert6*(10**-12))**2))/(h*((5**2)-(4**2)))*10**9

qw6=np.sqrt((((16*m*Mittelwert6*(10**-12)*c)/(h*((5**2)-(4**2))))*(Fehler6*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge7

# %%
W7=(c*8*m*((Mittelwert7*(10**-12))**2))/(h*((5**2)-(4**2)))*10**9

qw7=np.sqrt((((16*m*Mittelwert7*(10**-12)*c)/(h*((5**2)-(4**2))))*(Fehler7*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge8

# %%
W8=(c*8*m*((Mittelwert8*(10**-12))**2))/(h*((5**2)-(4**2)))*10**9

qw8=np.sqrt((((16*m*Mittelwert8*(10**-12)*c)/(h*((5**2)-(4**2))))*(Fehler8*(10**-12)))**2)*10**9

# %% [markdown]
# Wellenlänge9

# %%
W9=(c*8*m*((Mittelwert9*(10**-12))**2))/(h*((7**2)-(6**2)))*10**9

qw9=np.sqrt((((16*m*Mittelwert9*(10**-12)*c)/(h*((7**2)-(6**2))))*(Fehler9*(10**-12)))**2)*10**9

# %% [markdown]
# # Wellenzahl Experimentell

# %%
wze1=1/(w1e*10**-9)*(0.01)
wze2=1/(w2e*10**-9)*(0.01)
wze3=1/(w3e*10**-9)*(0.01)
wze4=1/(w4e*10**-9)*(0.01)
wze5=1/(w5e*10**-9)*(0.01)
wze6=1/(w6e*10**-9)*(0.01)
wze7=1/(w7e*10**-9)*(0.01)
wze8=1/(w8e*10**-9)*(0.01)
wze9=1/(w9e*10**-9)*(0.01)

# %% [markdown]
# # Wellenzahl Theorie

# %%
wz1=(1/(W1*10**-9))*(0.01)
wz2=(1/(W2*10**-9))*(0.01)
wz3=(1/(W3*10**-9))*(0.01)
wz4=(1/(W4*10**-9))*(0.01)
wz5=(1/(W5*10**-9))*(0.01)
wz6=(1/(W6*10**-9))*(0.01)
wz7=(1/(W7*10**-9))*(0.01)
wz8=(1/(W8*10**-9))*(0.01)
wz9=(1/(W9*10**-9))*(0.01)

# %% [markdown]
# Fehler Wellenzahl

# %%
qwz1=((-1/((W1*1e-9)**2))*(qw1*1e-9))*(0.01)
qwz2=((-1/((W2*1e-9)**2))*(qw2*1e-9))*(0.01)
qwz3=((-1/((W3*1e-9)**2))*(qw3*1e-9))*(0.01)
qwz4=((-1/((W4*1e-9)**2))*(qw4*1e-9))*(0.01)
qwz5=((-1/((W5*1e-9)**2))*(qw5*1e-9))*(0.01)
qwz6=((-1/((W6*1e-9)**2))*(qw6)*1e-9)*(0.01)
qwz7=((-1/((W7*1e-9)**2))*(qw7*1e-9))*(0.01)
qwz8=((-1/((W8*1e-9)**2))*(qw8*1e-9))*(0.01)
qwz9=((-1/((W9*1e-9)**2))*(qw9*1e-9))*(0.01)

# %%
qwz_values = [
    wze1, wze2, wze3, wze4, wze5, wze6, wze7, wze8, wze9  # Deine berechneten Werte
]
for i, wze in enumerate(qwz_values):
    print(f"wze{i+1} = {wze}")
# Out:
# wze1 = 23640.66193853428
# wze2 = 17921.14695340502
# wze3 = 15313.935681470137
# wze4 = 13192.612137203165
# wze5 = 20746.88796680498
# wze6 = 16528.92561983471
# wze7 = 17889.087656529515
# wze8 = 18450.18450184502
# wze9 = 14144.271570014143
