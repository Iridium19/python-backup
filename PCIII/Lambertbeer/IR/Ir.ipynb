# %% [markdown]
# Datenimport

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit
import io
import sympy as sp
import scipy.constants as kon

wellenlängel05, Intensitätl05=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Luft_050.dpt', skiprows=0, delimiter='\t', unpack=True)
wellenlängel05i, Intensitätl05i=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Luft_05_inter0.dpt', skiprows=0, delimiter='\t', unpack=True)
wellenlängel80, Intensitätl80=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Luft_80.dpt', skiprows=0, delimiter='\t', unpack=True)
wellenlängeM02bg, IntensitätM02bg0=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Methan_p02_bg0.dpt', skiprows=0, delimiter='\t', unpack=True)
wellenlängeM02, IntensitätM02=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Methan_p02_probe0.dpt', skiprows=0, delimiter='\t', unpack=True)
wellenlängeM80, IntensitätM80=np.loadtxt(r'C:\Users\Justus\Desktop\IR\Gr_12_Methan_p080.dpt', skiprows=0, delimiter='\t', unpack=True)
rzweig, ir=np.loadtxt(r'C:\Users\Justus\Desktop\IR\rzweig.csv', delimiter='\t', skiprows=0,  unpack=True)
pzweig=np.loadtxt(r'C:\Users\Justus\Desktop\IR\p-zweig.csv',skiprows=0,  unpack=True)

# %% [markdown]
# Spektren

# %%
fig, ax = plt.subplots()
major_ticks = range(500, 4000, 500)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(500, 4000, 100)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche



plt.plot(wellenlängel05, Intensitätl05,label='Luft 0.5$cm^{-1}$',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Intensität [w.E]')
plt.xlim(600,4000)



plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Intensität [w.E]')
plt.xlim(600,4000)

plt.show()

# %% [markdown]
# Wellenzahl 8

# %%
fig, ax = plt.subplots()
major_ticks = range(500, 4000, 500)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(500, 4000, 100)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche
plt.plot(wellenlängel80, Intensitätl80,label='Luft 8$cm^{-1}$',linewidth='0.3', color='black')


plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Intensität [w.E]')
plt.xlim(600,4000)
plt.show()

# %% [markdown]
# CO2 2200-2400

# %%
fig, ax = plt.subplots()
major_ticks = range(2200, 2400, 25)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(2200, 2400, 5)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche

plt.plot(wellenlängel05, Intensitätl05,linewidth='0.3', color='black')

plt.xlim(2250,2400)
plt.vlines(ymin=0,ymax=0.09,x=2348.96888,linewidth=1,label='$\sigma$')
plt.ylabel('Intensität [w.E]')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylim(0,0.09)
plt.legend()
plt.show()

sigmaCO2=2348.96888
usigmaCO2=0.25

omega= ((kon.c*sigmaCO2*10**2*kon.h)/ kon.hbar)
uomega= np.sqrt(((kon.c*kon.h/kon.hbar)*usigmaCO2*10**2)**2)

reduziertemasseco2= 7.245988*10**(-27)
KCO2= omega**2*reduziertemasseco2

uKCO2=np.sqrt(2*omega*reduziertemasseco2*uomega)

print(KCO2,'$KCO_2$')
print(uKCO2,'$uKCO_2$')


print([omega*10**(-14)],'$\omega$')
print([uomega*10**(-10)],'$\sigma\omega$')
# Out:
# 1418.57819263163 $KCO_2$
# 0.5495067230441534 $uKCO_2$
# [4.424638912371721] $\omega$
# [np.float64(4.709128918272133)] $\sigma\omega$

# %% [markdown]
# CO2 620-720

# %%
fig, ax = plt.subplots()
major_ticks = range(600, 720, 20)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(600, 720, 4)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche

plt.plot(wellenlängel05, Intensitätl05,linewidth='0.3', color='black')

plt.vlines(ymin=0,ymax=0.05,x=667.82755,linewidth=1,label='$\sigma$')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Intensität [w.E]')
plt.ylim(0,0.05)
plt.xlim(620,720)

plt.legend()
plt.show()



sigmaCO2=667.82755
usigmaCO2=0.25

omega= ((kon.c*sigmaCO2*10**2*kon.h)/ kon.hbar)
uomega= np.sqrt(((kon.c*kon.h/kon.hbar)*usigmaCO2*10**2)**2)

reduziertemasseco2= 3.622*10**(-27)
KCO2= omega**2*reduziertemasseco2

uKCO2=np.sqrt(2*omega*reduziertemasseco2*uomega)

print(KCO2,'$KCO_2$')
print(uKCO2,'$uKCO_2$')


print([omega*10**-14],'$\omega$')
print([uomega*10**-14],'$\sigma\omega$')
# Out:
# 57.31631367432966 $KCO_2$
# 0.20715335051158992 $uKCO_2$
# [1.2579544112495313] $\omega$
# [np.float64(0.0004709128918272133)] $\sigma\omega$

# %%
wellenlängel05i1=wellenlängel05i*3.164*10**(-5)


plt.plot(wellenlängel05i1, Intensitätl05i,label='Luft 0.5$cm^{-1}$',linewidth='0.3', color='black')
plt.xlabel("Spiegelweg")
plt.ylabel("Amplitude")
plt.xlim(0,3)

plt.show()

# %% [markdown]
# Formier Trnasformation

# %%
import numpy as np
import matplotlib.pyplot as plt
wellenlängel05i1=wellenlängel05i*3.164*10**(-5)

# Beispiel für ein Interferogramm: Ein einfaches sinusförmiges Signal (Interferogramm)
# Ersetze diese Daten mit deinem eigenen Interferogramm
x_data = wellenlängel05i1  # Zeit oder Positionswerte
y_data = Intensitätl05i

# Durchführung der Fourier-Transformation
y_fft = np.fft.fft(y_data)

# Berechnung der Frequenzen
sampling_interval = x_data[1] - x_data[0]  # Abtastintervall
sampling_rate = 1 / sampling_interval  # Abtastrate
frequencies = np.fft.fftfreq(len(x_data), d=sampling_interval)  # Frequenzwerte

# Nur die positiven Frequenzen verwenden
positive_frequencies = frequencies[:len(frequencies)//2]
positive_y_fft = y_fft[:len(frequencies)//2]

# Plotten des Interferogramms und seines Frequenzspektrums
plt.figure(figsize=(12, 6))

# Originales Interferogramm
plt.subplot(1, 2, 1)
plt.plot(x_data, y_data,linewidth='0.3',color='black')
#plt.title("Interferogramm")
plt.xlabel("Spiegelweg [w.E.]")
plt.ylabel("Amplitude [w.E.]")
plt.xlim(0,3)



# Fourier-Spektrum
plt.subplot(1, 2, 2)
plt.plot(positive_frequencies, np.abs(positive_y_fft), linewidth='0.3',color='black')
#plt.title("Frequenzspektrum (Fourier-Transformation)")
plt.xlim(200,8000)
plt.xlabel("Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$")
plt.ylabel('Intensität [w.E]')

plt.tight_layout()
plt.show()

# %% [markdown]
# Methan

# %%
fig, ax = plt.subplots()
major_ticks = range(500, 4000, 500)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(500, 4000, 100)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche
plt.plot(wellenlängeM02bg, IntensitätM02bg0,linewidth='0.3', color='black')
plt.ylabel('Intensität [w.E]')
plt.xlabel("Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$")
plt.xlim(600,4000)


plt.show()

# %% [markdown]
# Methan 0.2 PRobe

# %%
fig, ax = plt.subplots()
major_ticks = range(500, 4000, 500)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(500, 4000, 100)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche

plt.plot(wellenlängeM02, IntensitätM02,label='Methan 0.2 bar',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Intensität [w.E]')
plt.xlim(600,4000)


plt.show()

# %% [markdown]
# Methan 0.2 normiert

# %%
fig, ax = plt.subplots()
major_ticks = range(500, 4000, 500)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(500, 4000, 100)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche


ghf=IntensitätM02/IntensitätM02bg0

plt.plot(wellenlängeM02, ghf,label='Methan 0.2 bar',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Transmission')
plt.xlim(600,4000)
plt.show()

# %% [markdown]
# Methan02 1200 1400

# %%
fig, ax = plt.subplots()
major_ticks = range(1200, 1400, 25)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(1200, 1400, 5)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche


ghf=IntensitätM02/IntensitätM02bg0

plt.plot(wellenlängeM02, ghf,label='Methan 0.2 bar',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Transmission')

print(min(ghf)) # bei 1306

plt.xlim(1200,1400)
plt.show()
# Out:
# 0.004008633980881899

# %% [markdown]
# Methan 02 2550 2650

# %%
fig, ax = plt.subplots()
major_ticks = range(2550, 2650, 10)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(2550, 2650, 2)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche


ghf=IntensitätM02/IntensitätM02bg0

plt.plot(wellenlängeM02, ghf,label='Methan 0.2 bar',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Transmission')

plt.ylim(0.8,1.02)
plt.xlim(2550,2650)
plt.show()

# %% [markdown]
# Methan 0.8

# %%
fig, ax = plt.subplots()
major_ticks = range(2550, 2650, 10)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(2550, 2650, 2)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche

plt.plot(wellenlängeM80, IntensitätM80,label='Methan 0.8 bar',linewidth='0.3', color='black')


plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Transmission')

plt.ylim(0.8,1.01)
plt.xlim(2550,2650)
plt.show()

# %% [markdown]
# methan 0.2 2800 3300

# %%
fig, ax = plt.subplots()
major_ticks = range(2800, 3300, 100)
ax.set_xticks(major_ticks)
ax.set_xticklabels(major_ticks)  # Zeigt die Zahlen an

# Nebenticks (100er) → Kleine Striche, aber ohne Beschriftung
minor_ticks = range(2800, 3300, 20)
ax.set_xticks(minor_ticks, minor=True)  # Setzt die kleinen Ticks
ax.tick_params(axis='x', which='major', length=10, width=1)  # Große Striche
ax.tick_params(axis='x', which='minor', length=5, width=1)  # Kleine Striche

ghf=IntensitätM02/IntensitätM02bg0

plt.plot(wellenlängeM02, ghf,label='Methan 0.2 bar',linewidth='0.3', color='black')

plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.ylabel('Transmission')

plt.xlim(2800,3300)
plt.show()

# %% [markdown]
# Minimas 2800 3300

# %%
import numpy as np
import scipy.signal
ghf=IntensitätM02/IntensitätM02bg0





def find_local_minima(x, y):
    """
    Findet alle lokalen Minima in einem gegebenen Datensatz (x, y), wobei eine Mindestdifferenz
    von 0.3 zum nächsten lokalen Maximum eingehalten wird.
    
    :param x: Liste oder numpy-Array mit den x-Werten
    :param y: Liste oder numpy-Array mit den y-Werten
    :return: Liste mit Tupeln (x_min, y_min) der gefundenen Minima
    """
    x = wellenlängeM02
    y = ghf
    
    minima_indices = scipy.signal.argrelextrema(y, np.less)[0]
    
    # Nur Minima unter y=0.7 behalten
    minima = [(x[i], y[i]) for i in minima_indices if y[i] < 0.7]
    
    # Minima filtern, sodass sie mindestens 7 x-Einheiten voneinander entfernt sind
    filtered_minima = []
    for x_min, y_min in minima:
        if not filtered_minima or abs(x_min - filtered_minima[-1][0]) >= 7:
            filtered_minima.append((x_min, y_min))
        else:
            # Falls zu nah, behalte nur das tiefere Minimum
            if y_min < filtered_minima[-1][1]:
                filtered_minima[-1] = (x_min, y_min)
    
    return filtered_minima

x = wellenlängeM02
y = ghf

# Lokale Minima finden
minima = find_local_minima(x, y)

# Plot erstellen

plt.plot(x, y, label='Daten',color='black',linewidth=0.3)


plt.xlabel('Wellenzahl ${[\\tilde{\\nu}]=\\frac{1}{cm}}$')
plt.vlines(x=rzweig, ymin=0,ymax=1, color='red', linestyles='-', label='R-Zweig',linewidth=0.5)
plt.vlines(x=pzweig, ymin=0,ymax=1, color='red', linestyles='-',label='Pzweig',linewidth=0.5)

plt.xlim(2800,3300)
plt.title('Lokale Minima')
plt.show()

# Ergebnisse ausgeben
for x_min, y_min in minima:
    print(f"Lokales Minimum bei x={x_min:.2f}, y={y_min:.2f}")
# Out:
# Lokales Minimum bei x=3166.52, y=0.70
# Lokales Minimum bei x=3158.08, y=0.62
# Lokales Minimum bei x=3149.40, y=0.46
# Lokales Minimum bei x=3140.48, y=0.35
# Lokales Minimum bei x=3131.80, y=0.36
# Lokales Minimum bei x=3122.88, y=0.28
# Lokales Minimum bei x=3113.72, y=0.24
# Lokales Minimum bei x=3104.80, y=0.23
# Lokales Minimum bei x=3095.63, y=0.25
# Lokales Minimum bei x=3086.23, y=0.20
# Lokales Minimum bei x=3076.83, y=0.29
# Lokales Minimum bei x=3067.43, y=0.28
# Lokales Minimum bei x=3058.02, y=0.28
# Lokales Minimum bei x=3048.38, y=0.42
# Lokales Minimum bei x=3038.74, y=0.52
# Lokales Minimum bei x=3029.09, y=0.47
# Lokales Minimum bei x=3017.76, y=0.00
# Lokales Minimum bei x=3009.08, y=0.33
# Lokales Minimum bei x=2999.20, y=0.43
# Lokales Minimum bei x=2989.07, y=0.25
# Lokales Minimum bei x=2979.19, y=0.16
# Lokales Minimum bei x=2968.82, y=0.13
# Lokales Minimum bei x=2958.69, y=0.07
# Lokales Minimum bei x=2948.33, y=0.08
# Lokales Minimum bei x=2937.96, y=0.16
# Lokales Minimum bei x=2927.35, y=0.15
# Lokales Minimum bei x=2916.98, y=0.24
# Lokales Minimum bei x=2906.86, y=0.42
# Lokales Minimum bei x=2895.53, y=0.38
# Lokales Minimum bei x=2885.40, y=0.52
# Lokales Minimum bei x=2875.03, y=0.60
# Lokales Minimum bei x=1368.68, y=0.56
# Lokales Minimum bei x=1355.67, y=0.39
# Lokales Minimum bei x=1341.92, y=0.27
# Lokales Minimum bei x=1332.52, y=0.21
# Lokales Minimum bei x=1322.15, y=0.55
# Lokales Minimum bei x=1306.00, y=0.01
# Lokales Minimum bei x=1297.80, y=0.30
# Lokales Minimum bei x=1283.34, y=0.40
# Lokales Minimum bei x=1271.52, y=0.50
# Lokales Minimum bei x=1259.95, y=0.46
# Lokales Minimum bei x=1247.90, y=0.53
# Lokales Minimum bei x=668.07, y=0.55

# %% [markdown]
# Berechnung B' B''

# %%
w11,w22,banz1=np.loadtxt(r'C:\Users\Justus\Desktop\IR\B1.csv', skiprows=0,  unpack=True)
w1,w2,Banz=np.loadtxt(r'C:\Users\Justus\Desktop\IR\B2.csv', skiprows=0,  unpack=True)

dif1=w11-w22
dif2=w1-w2
B1array=dif1/banz1
B2array=dif2/Banz    
print(dif1,'Differnz',banz1,'AnzahlBs',B1array,'B')
B1=np.mean(B1array)*10**2
B2=np.mean(B2array)*10**2
print(B1,'B1')
print(B2,'B2')
uB1=np.std(B1array)*10**2
uB2=np.std(B2array)*10**2

print(uB1,'uB1')
print(uB2,'uB2')
#b2grundzustand
# Out:
# [ 29.89  49.67  69.19  89.2  108.74 128.5  148.27 168.28 187.82 206.86] Differnz [ 6. 10. 14. 18. 22. 26. 30. 34. 38. 42.] AnzahlBs [4.98166667 4.967      4.94214286 4.95555556 4.94272727 4.94230769
#  4.94233333 4.94941176 4.94263158 4.9252381 ] B
# 494.9101481662472 B1
# 497.7750730135865 B2
# 1.4882663846106388 uB1
# 1.2570327106239396 uB2

# %% [markdown]
# Bindungslänge

# %%
mr1=4.04756362*10**(-27)
mr=8/3*kon.u



r1=np.sqrt(kon.h/(8*kon.pi**2*kon.c*B1*mr))
r2=np.sqrt(kon.h/(8*kon.pi**2*kon.c*B2*mr))

print(r1,'r1')
print(r2,'r2')

ur1=np.sqrt((-kon.h/(2**(5/2)*kon.pi*kon.c*mr*np.sqrt(kon.h/(kon.c*mr*B1))*B1**2)*uB1)**2)
ur2=np.sqrt((-kon.h/(2**(5/2)*kon.pi*kon.c*mr*np.sqrt(kon.h/(kon.c*mr*B2))*B2**2)*uB2)**2)

print(ur1,'ur1')
print(ur2,'ur2')
# Out:
# 1.130188027437578e-10 r1
# 1.1269309578290431e-10 r2
# 1.6993194176326923e-13 ur1
# 1.422920866677478e-13 ur2

# %%
from scipy.optimize import curve_fit

def linearfit(m,x,t):
    return(m*x+t)

x=[1,2]
y=[1305.66,1283.17]
parameter, fehler= curve_fit(linearfit,x,y,p0=(-7.5,1270))
m,t=parameter


h=np.linspace(0,3,1000)
plt.plot(h,m*h+t,color='black',label='Lineare Regression')

plt.scatter(x,y,color='red',marker='x', label='Datenpunkte',zorder=1000)
plt.legend()
plt.xlim(0.5,2.5)

plt.show()

print(m,'cm-1')
#print(m_err,'m_err')
print(t,'t')
#print(t_err,'t_err')


xe=-m/(2*t)
print(xe,'xe')

De=kon.h*kon.c*t*10**2/(4*xe)
print(De,'De')


D0=De-1/2*kon.h*kon.c*t*10**2

print(D0,'D0')

D0KJ=D0*kon.N_A/1000

print(D0KJ,'D0KJ')
# Out:
# C:\Users\Justus\AppData\Local\Temp\ipykernel_6356\3064253163.py:8: OptimizeWarning: Covariance of the parameters could not be estimated
#   parameter, fehler= curve_fit(linearfit,x,y,p0=(-7.5,1270))
# -22.490000000000023 cm-1
# 1328.15 t
# 0.008466664156909996 xe
# 7.790252501686644e-19 De
# 7.658337598428027e-19 D0
# 461.1958700533393 D0KJ
